# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
clases=["A","B","C","D","E"]
std1=[12,10,11,13,14]
std2=[7,8,5,6,3]
std3=[15,11,18,16,17]

# %%
plt.bar(clases,std1,width=0.2,align='center',color="m",edgecolor="black",linewidth=3,linestyle="-.")
# Out:
# <BarContainer object of 5 artists>
