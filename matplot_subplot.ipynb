# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
std1=np.random.randint(15,45,(100))
std2=np.random.randint(18,40,(100))

# %%
plt.subplot(2,2,1)#two col two rows and one index
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)
plt.pie([1])
plt.subplot(2,2,2)
plt.pie([1,2])
plt.subplot(2,2,3)
plt.pie([1,2,3])
plt.subplot(2,2,4)
plt.pie([1,2,3,4])
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(3,2,1)

days=[1,2,3,4,5,6,7]
temp=[23.4,45.5,23,67.90,18,40,50]
plt.plot(days,temp,color='b',marker='o',linestyle="--",linewidth="2",markersize="10")
plt.axis([0,8,20,50])
plt.title('this is temperatur of week ')
plt.xlabel('days',loc='center')
plt.ylabel('temp',loc='top')
plt.subplot(3,2,2)
plt.hist(std1,bins=20,rwidth=0.8)
plt.title("histogram")
plt.xlabel("std age")
plt.ylabel('std catag')
plt.subplot(3,2,3)
plt.subplot(3,2,4)
std=["A","B","C","D"]
marks=[22,34,55,67]
explode=[0,0.2,0,0.1]
colors=['r','b','black','g']
textprops={"fontsize":14}

plt.pie(marks,labels=std,explode=explode,colors=colors,autopct="%0.2f%%",textprops=textprops)
plt.legend()
plt.show()
plt.subplot(3,2,5)
plt.subplot(3,2,6,projection='polar',facecolor='g')
#plt.subplot(326) same result
# Out:
# <PolarAxes: >
