# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # all figures can save in the same way

# %%
plt.pie([30,40,20])
plt.savefig("pie_chart",dpi=1000,facecolor='w',edgecolor='g')# by default give pie chart
plt.show()

# %% [markdown]
# # we can chage path of fig

# %%
plt.pie([30,40,20])
plt.savefig("C:\\Users\Mr\\Desktop\\New folder\\pie_char.png",dpi=1000,facecolor='w',edgecolor='g')# by default give pie chart
plt.show()
