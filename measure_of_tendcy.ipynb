# %% [markdown]
# # data cleaning by class mean and impute numerical value

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\Mr\\Desktop\\python\\hose_prediction.csv",parse_dates=["date"])

# %%
df.shape

# %%
df.head()

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df1=df.select_dtypes(include=['int64','float64'])
df1.columns

# %%
df.isnull().sum().sum()

# %%
miss_value_per=df1.isnull().sum()/df.shape[0]*100
miss_value_per

# %%
miss_value=['price','view','yr_built','sqft_lot']
df1[miss_value][df1[miss_value].isnull().any(axis=1)]
# Out:
#          price  view  yr_built  sqft_lot
# 4     550000.0   0.0       NaN   10500.0
# 6     335000.0   NaN       NaN    2560.0
# 7     482000.0   0.0       NaN   35868.0
# 8     452500.0   NaN    1985.0   88426.0
# 9          NaN   9.0    1945.0    6200.0
# 10    463000.0   0.0       NaN    7320.0
# 13    365000.0   0.0       NaN    6435.0
# 14         NaN   0.0    1939.0    9480.0
# 15    242500.0   0.0       NaN    9720.0
# 17    367500.0   NaN       NaN    7231.0
# 19    275000.0   0.0       NaN   10277.0
# 20    750000.0   NaN    1923.0   10578.0
# 21    435000.0   0.0       NaN    8800.0
# 22         NaN   0.0    2005.0    1572.0
# 23    612500.0   NaN    1991.0   12261.0
# 25    285000.0   NaN    1987.0   10834.0
# 27    698000.0   NaN    1920.0   11250.0
# 29         NaN   0.0    1951.0    4750.0
# 34         NaN   0.0    1979.0   42884.0
# 36    440000.0   NaN    1944.0    4850.0
# 37    287200.0   0.0       NaN   19966.0
# 38         NaN   2.0    1957.0   13100.0
# ...
