# %% [markdown]
# # Exploratory Data Analysis On Mental Health Data

# %% [markdown]
# # about data
# - Description:
# data set was downloaded from kaggle

# %% [markdown]
# # 01:Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 02: loading data

# %%
df=pd.read_csv("Mental Health Dataset.csv")

# %%
#df.to_excel("Mental_Health_Dataset.xlsx", index=False)

# %% [markdown]
# # 03: meta data

# %% [markdown]
# #  cols and rows

# %%
print('rows are:',df.shape[0])
print("cols are: ",df.shape[1])
# Out:
# rows are: 292364
# cols are:  17

# %%
df.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Mood_Swings',
#        'Coping_Struggles', 'Work_Interest', 'Social_Weakness',
#        'mental_health_interview', 'care_options'],
#       dtype='object')

# %% [markdown]
# # Droping unnecessary columns

# %%
df=df.drop(columns=['Mood_Swings'],axis=1)
df=df.drop(columns=['Social_Weakness'],axis=1)
df=df.drop(columns=['Work_Interest'],axis=1)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Coping_Struggles',
#        'mental_health_interview', 'care_options'],
#       dtype='object')

# %%
df=pd.DataFrame(df)
df
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
df.Days_Indoors.unique()
# Out:
# array(['1-14 days', 'Go out Every day', 'More than 2 months',
#        '15-30 days', '31-60 days'], dtype=object)

# %%
df. Timestamp.unique()
# Out:
# array(['8/27/2014 11:29', '8/27/2014 11:31', '8/27/2014 11:32',
#        '8/27/2014 11:37', '8/27/2014 11:43', '8/27/2014 11:49',
#        '8/27/2014 11:51', '8/27/2014 11:52', '8/27/2014 12:18',
#        '8/27/2014 12:37', '8/27/2014 12:39', '8/27/2014 12:40',
#        '8/27/2014 12:49', '8/27/2014 12:50', '8/27/2014 12:51',
#        '8/27/2014 12:53', '8/27/2014 12:55', '8/27/2014 12:57',
#        '8/27/2014 13:06', '8/27/2014 13:31', '8/27/2014 13:47',
#        '8/27/2014 13:49', '8/27/2014 13:55', '8/27/2014 14:11',
#        '8/27/2014 14:13', '8/27/2014 14:16', '8/27/2014 14:19',
#        '8/27/2014 14:27', '8/27/2014 14:31', '8/27/2014 14:52',
#        '8/27/2014 15:22', '8/27/2014 15:24', '8/27/2014 15:29',
#        '8/27/2014 15:34', '8/27/2014 15:35', '8/27/2014 15:36',
#        '8/27/2014 16:02', '8/27/2014 16:14', '8/27/2014 16:19',
#        '8/27/2014 16:21', '8/27/2014 16:25', '8/27/2014 16:27',
#        '8/27/2014 16:35', '8/27/2014 16:42', '8/27/2014 17:08',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                292364 non-null  object
#  1   Gender                   292364 non-null  object
#  2   Country                  292364 non-null  object
#  3   Occupation               292364 non-null  object
#  4   self_employed            287162 non-null  object
#  5   family_history           292364 non-null  object
#  6   treatment                292364 non-null  object
#  7   Days_Indoors             292364 non-null  object
#  8   Growing_Stress           292364 non-null  object
#  9   Changes_Habits           292364 non-null  object
#  10  Mental_Health_History    292364 non-null  object
#  11  Coping_Struggles         292364 non-null  object
#  12  mental_health_interview  292364 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Coping_Struggles              0
# mental_health_interview       0
# care_options                  0
# dtype: int64

# %% [markdown]
# # impute null values

# %%
import pandas as pd

# Assuming df is your DataFrame
df['self_employed'].fillna(df['self_employed'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Coping_Struggles           0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
df.describe()
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# count            292364  292364         292364     292364        292364
# unique              580       2             35          5             2
# top     8/27/2014 11:43    Male  United States  Housewife            No
# freq               2384  239850         171308      66351        263196
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# count          292364    292364       292364         292364         292364
# unique              2         2            5              3              3
# top                No       Yes    1-14 days          Maybe            Yes
# freq           176832    147606        63548          99985         109523
#
#        Mental_Health_History Coping_Struggles mental_health_interview  \
# count                 292364           292364                  292364
# unique                     3                2                       3
# ...

# %% [markdown]
# # value count funtion to count male and female

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      239850
# Female     52514
# Name: count, dtype: int64

# %% [markdown]
# # feature encoding
# - label encoding

# %%
df.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Coping_Struggles',
#        'mental_health_interview', 'care_options'],
#       dtype='object')

# %%
df[['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed','Changes_Habits','Growing_Stress', #family_history' 'treatment', 'Growing_Stress','Changes_Habits', 'Mental_Health_History', 'Coping_Struggles''mental_health_interview', #'care_options'
    ]]
# Out:
#         Timestamp  Gender        Country Occupation self_employed  \
# 0              39       0  United States  Corporate            No
# 1              41       0  United States  Corporate            No
# 2              42       0  United States  Corporate            No
# 3              47       0  United States  Corporate            No
# 4              52       0  United States  Corporate            No
# ...           ...     ...            ...        ...           ...
# 292359         36       1  United States   Business           Yes
# 292360         37       1   South Africa   Business            No
# 292361         38       1  United States   Business            No
# 292362        570       1  United States   Business            No
# 292363          4       1  United States   Business            No
#
#        Changes_Habits Growing_Stress
# 0                  No            Yes
# 1                  No            Yes
# 2                  No            Yes
# ...

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
df['Gender']=le.fit_transform(df.Gender.values)
df['Timestamp']=le.fit_transform(df['Timestamp'])

# %%
df.Gender.value_counts()
# Out:
# Gender
# 1    239850
# 0     52514
# Name: count, dtype: int64

# %% [markdown]
# ## one hot coding

# %%
dumies=pd.get_dummies(df.self_employed)
dumies
# Out:
#            No    Yes
# 0        True  False
# 1        True  False
# 2        True  False
# 3        True  False
# 4        True  False
# ...       ...    ...
# 292359  False   True
# 292360   True  False
# 292361   True  False
# 292362   True  False
# 292363   True  False
#
# [292364 rows x 2 columns]

# %% [markdown]
# # merge dumies and df

# %%
df1=pd.concat([df,dumies],axis='columns')

# %%
df1.head(6)
# Out:
#    Timestamp  Gender        Country Occupation self_employed family_history  \
# 0         39       0  United States  Corporate            No             No
# 1         41       0  United States  Corporate            No            Yes
# 2         42       0  United States  Corporate            No            Yes
# 3         47       0  United States  Corporate            No            Yes
# 4         52       0  United States  Corporate            No            Yes
# 5         56       0         Poland  Corporate            No             No
#
#   treatment Days_Indoors Growing_Stress Changes_Habits  ... Poland Portugal  \
# 0       Yes    1-14 days            Yes             No  ...  False    False
# 1       Yes    1-14 days            Yes             No  ...  False    False
# 2       Yes    1-14 days            Yes             No  ...  False    False
# 3       Yes    1-14 days            Yes             No  ...  False    False
# ...

# %% [markdown]
# # droping country from orignal data

# %%
df2=df1.drop('Country',axis='columns')
df2
# Out:
#         Timestamp  Gender Occupation self_employed family_history treatment  \
# 0              39       0  Corporate            No             No       Yes
# 1              41       0  Corporate            No            Yes       Yes
# 2              42       0  Corporate            No            Yes       Yes
# 3              47       0  Corporate            No            Yes       Yes
# 4              52       0  Corporate            No            Yes       Yes
# ...           ...     ...        ...           ...            ...       ...
# 292359         36       1   Business           Yes            Yes       Yes
# 292360         37       1   Business            No            Yes       Yes
# 292361         38       1   Business            No            Yes        No
# 292362        570       1   Business            No            Yes       Yes
# 292363          4       1   Business            No            Yes       Yes
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                292364 non-null  int32
#  1   Gender                   292364 non-null  int32
#  2   Occupation               292364 non-null  object
#  3   self_employed            292364 non-null  object
#  4   family_history           292364 non-null  object
#  5   treatment                292364 non-null  object
#  6   Days_Indoors             292364 non-null  object
#  7   Growing_Stress           292364 non-null  object
#  8   Changes_Habits           292364 non-null  object
#  9   Mental_Health_History    292364 non-null  object
#  10  Coping_Struggles         292364 non-null  object
#  11  mental_health_interview  292364 non-null  object
#  12  care_options             292364 non-null  object
# ...
